# %% [markdown]
# # MPC/SBN Database Tests (June 2023)
#
# This code uses the Rubin Observatory replica at University of Washington.

# %% [markdown]
# ## Getting this notebook
#
# This notebook is designed to be run from the LINCC JupyterHub at:
#
#     https://lsst.dirac.dev
#
# (though you can run it from your own machine with small changes).
#
# The notebook is available from https://github.com/mjuric/mpc-sbn-tests. To obtain it, open a terminal and clone it into your home directory to run it:
#
#     git clone https://github.com/mjuric/mpc-sbn-tests
# .

# %% [markdown]
# ## Connecting and inspecting available tables

# %%
import psycopg2 as pg
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %%
pwd = open("/home/shared/sssc-db-pass.txt").read()
con = pg.connect(database="mpc_sbn", user="sssc", password=pwd, host="epyc.astro.washington.edu", port="5432")

# %% [markdown]
# See which tables are available:

# %%
tables = pd.read_sql("SELECT table_name FROM information_schema.tables WHERE table_schema = 'public'", con)
tables = tables.set_index("table_name")
tables
# Out:
# Empty DataFrame
# Columns: []
# Index: [neocp_els, neocp_events, neocp_obs, neocp_obs_archive, neocp_prev_des, neocp_var, obs_sbn, mpc_orbits, current_identifications, numbered_identifications, primary_objects, obs_alterations_corrections, obs_alterations_deletions, obs_alterations_redesignations, obs_alterations_unassociations]

# %% [markdown]
# See how many rows each table has (this takes awhile to run -- ~10 minutes or so):

# %%
# %%time
tables["nrows"] = np.zeros(len(tables), dtype=int)
for table in tables.index:
    df = pd.read_sql(f"SELECT COUNT(*) FROM {table}", con, params=dict(table=table))
    tables["nrows"].loc[table] = df["count"].iloc[0]

# %%
tables
# Out:
#                                     nrows
# table_name
# neocp_els                              21
# neocp_events                       182534
# neocp_obs                             281
# neocp_obs_archive                  476542
# neocp_prev_des                      54088
# neocp_var                           43476
# obs_sbn                         396010031
# mpc_orbits                        1284248
# current_identifications           1821172
# numbered_identifications           620865
# primary_objects                   1350122
# obs_alterations_corrections             0
# obs_alterations_deletions          906668
# obs_alterations_redesignations       2396
# obs_alterations_unassociations      19366

# %% [markdown]
# List indices we have on the database:

# %%
query = """
SELECT
    tablename,
    indexname,
    indexdef
FROM
    pg_indexes
WHERE
    schemaname = 'public'
ORDER BY
    tablename,
    indexname;
"""
pd.read_sql(query, con)
# Out:
#                          tablename  \
# 0          current_identifications
# 1          current_identifications
# 2          current_identifications
# 3                       mpc_orbits
# 4                       mpc_orbits
# 5                       mpc_orbits
# 6                        neocp_els
# 7                        neocp_els
# 8                        neocp_els
# 9                        neocp_els
# 10                    neocp_events
# 11                    neocp_events
# 12                    neocp_events
# 13                    neocp_events
# 14                    neocp_events
# 15                       neocp_obs
# 16                       neocp_obs
# 17                       neocp_obs
# 18                       neocp_obs
# 19                       neocp_obs
# 20                       neocp_obs
# 21               neocp_obs_archive
# 22               neocp_obs_archive
# 23               neocp_obs_archive
# 24               neocp_obs_archive
# 25               neocp_obs_archive
# 26                  neocp_prev_des
# 27                  neocp_prev_des
# 28                  neocp_prev_des
# 29                  neocp_prev_des
# 30                  neocp_prev_des
# 31                  neocp_prev_des
# 32                  neocp_prev_des
# 33                       neocp_var
# 34                       neocp_var
# 35                       neocp_var
# 36        numbered_identifications
# 37        numbered_identifications
# 38        numbered_identifications
# 39        numbered_identifications
# 40        numbered_identifications
# 41     obs_alterations_corrections
# 42       obs_alterations_deletions
# 43  obs_alterations_redesignations
# 44  obs_alterations_unassociations
# 45                         obs_sbn
# 46                         obs_sbn
# 47                         obs_sbn
# 48                         obs_sbn
# 49                         obs_sbn
# 50                         obs_sbn
# 51                         obs_sbn
# 52                         obs_sbn
# 53                 primary_objects
# 54                 primary_objects
# 55                 primary_objects
# 56                 primary_objects
#
#                                             indexname  \
# 0   current_identifications_packed_primary_provisi...
# 1   current_identifications_packed_secondary_provi...
# 2                        current_identifications_pkey
# 3                                     mpc_orbits_pkey
# 4                      packed_primary_provisional_idx
# 5                    unpacked_primary_provisional_idx
# 6                            neocp_els_created_at_key
# 7                                 neocp_els_desig_key
# 8                               neocp_els_digest2_key
# 9                                      neocp_els_pkey
# 10                             neocp_events_desig_key
# 11                        neocp_events_event_text_key
# 12                        neocp_events_event_type_key
# 13                        neocp_events_event_user_key
# 14                                  neocp_events_pkey
# 15                           neocp_obs_created_at_key
# 16                                neocp_obs_desig_key
# 17                                     neocp_obs_pkey
# 18                            neocp_obs_substring_idx
# 19                                neocp_obs_trkid_key
# 20                           neocp_obs_updated_at_key
# 21                   neocp_obs_archive_created_at_key
# 22                        neocp_obs_archive_desig_key
# 23                             neocp_obs_archive_pkey
# 24                        neocp_obs_archive_trkid_key
# 25                   neocp_obs_archive_updated_at_key
# 26                      neocp_prev_des_created_at_key
# 27                           neocp_prev_des_desig_key
# 28                       neocp_prev_des_iau_desig_key
# 29                       neocp_prev_des_pkd_desig_key
# 30                                neocp_prev_des_pkey
# 31                             neocp_prev_des_ref_key
# 32                          neocp_prev_des_status_key
# 33                           neocp_var_created_at_key
# 34                                neocp_var_desig_key
# 35                                     neocp_var_pkey
# 36              numbered_identifications_iau_name_idx
# 37  numbered_identifications_packed_primary_provis...
# 38                numbered_identifications_permid_idx
# 39                      numbered_identifications_pkey
# 40  numbered_identifications_unpacked_primary_prov...
# 41                   obs_alterations_corrections_pkey
# 42                     obs_alterations_deletions_pkey
# 43                obs_alterations_redesignations_pkey
# 44                obs_alterations_unassociations_pkey
# 45                                obs_sbn_obstime_idx
# 46                                       obs_sbn_pkey
# 47                                    obs_sbn_stn_idx
# 48                    obs_sbn_submission_block_id_key
# 49                                  obs_sbn_trkid_idx
# 50                                 obs_sbn_trkmpc_idx
# 51                                 obs_sbn_trksub_idx
# 52                             obs_sbn_updated_at_idx
# 53  primary_objects_packed_primary_provisional_des...
# 54  primary_objects_packed_primary_provisional_des...
# 55                               primary_objects_pkey
# 56  primary_objects_unpacked_primary_provisional_d...
#
#                                              indexdef
# 0   CREATE INDEX current_identifications_packed_pr...
# 1   CREATE UNIQUE INDEX current_identifications_pa...
# 2   CREATE UNIQUE INDEX current_identifications_pk...
# 3   CREATE UNIQUE INDEX mpc_orbits_pkey ON public....
# 4   CREATE UNIQUE INDEX packed_primary_provisional...
# 5   CREATE UNIQUE INDEX unpacked_primary_provision...
# 6   CREATE INDEX neocp_els_created_at_key ON publi...
# 7   CREATE UNIQUE INDEX neocp_els_desig_key ON pub...
# 8   CREATE INDEX neocp_els_digest2_key ON public.n...
# 9   CREATE UNIQUE INDEX neocp_els_pkey ON public.n...
# 10  CREATE INDEX neocp_events_desig_key ON public....
# 11  CREATE INDEX neocp_events_event_text_key ON pu...
# 12  CREATE INDEX neocp_events_event_type_key ON pu...
# 13  CREATE INDEX neocp_events_event_user_key ON pu...
# 14  CREATE UNIQUE INDEX neocp_events_pkey ON publi...
# 15  CREATE INDEX neocp_obs_created_at_key ON publi...
# 16  CREATE INDEX neocp_obs_desig_key ON public.neo...
# 17  CREATE UNIQUE INDEX neocp_obs_pkey ON public.n...
# 18  CREATE INDEX neocp_obs_substring_idx ON public...
# 19  CREATE INDEX neocp_obs_trkid_key ON public.neo...
# 20  CREATE INDEX neocp_obs_updated_at_key ON publi...
# 21  CREATE INDEX neocp_obs_archive_created_at_key ...
# 22  CREATE INDEX neocp_obs_archive_desig_key ON pu...
# 23  CREATE UNIQUE INDEX neocp_obs_archive_pkey ON ...
# 24  CREATE INDEX neocp_obs_archive_trkid_key ON pu...
# 25  CREATE INDEX neocp_obs_archive_updated_at_key ...
# 26  CREATE INDEX neocp_prev_des_created_at_key ON ...
# 27  CREATE INDEX neocp_prev_des_desig_key ON publi...
# 28  CREATE INDEX neocp_prev_des_iau_desig_key ON p...
# 29  CREATE INDEX neocp_prev_des_pkd_desig_key ON p...
# 30  CREATE UNIQUE INDEX neocp_prev_des_pkey ON pub...
# 31  CREATE INDEX neocp_prev_des_ref_key ON public....
# 32  CREATE INDEX neocp_prev_des_status_key ON publ...
# 33  CREATE INDEX neocp_var_created_at_key ON publi...
# 34  CREATE INDEX neocp_var_desig_key ON public.neo...
# 35  CREATE UNIQUE INDEX neocp_var_pkey ON public.n...
# 36  CREATE UNIQUE INDEX numbered_identifications_i...
# 37  CREATE UNIQUE INDEX numbered_identifications_p...
# 38  CREATE UNIQUE INDEX numbered_identifications_p...
# 39  CREATE UNIQUE INDEX numbered_identifications_p...
# 40  CREATE UNIQUE INDEX numbered_identifications_u...
# 41  CREATE UNIQUE INDEX obs_alterations_correction...
# 42  CREATE UNIQUE INDEX obs_alterations_deletions_...
# 43  CREATE UNIQUE INDEX obs_alterations_redesignat...
# 44  CREATE UNIQUE INDEX obs_alterations_unassociat...
# 45  CREATE INDEX obs_sbn_obstime_idx ON public.obs...
# 46  CREATE UNIQUE INDEX obs_sbn_pkey ON public.obs...
# 47  CREATE INDEX obs_sbn_stn_idx ON public.obs_sbn...
# 48  CREATE INDEX obs_sbn_submission_block_id_key O...
# 49  CREATE INDEX obs_sbn_trkid_idx ON public.obs_s...
# 50  CREATE INDEX obs_sbn_trkmpc_idx ON public.obs_...
# 51  CREATE INDEX obs_sbn_trksub_idx ON public.obs_...
# 52  CREATE INDEX obs_sbn_updated_at_idx ON public....
# 53  CREATE UNIQUE INDEX primary_objects_packed_pri...
# 54  CREATE UNIQUE INDEX primary_objects_packed_pri...
# 55  CREATE UNIQUE INDEX primary_objects_pkey ON pu...
# 56  CREATE UNIQUE INDEX primary_objects_unpacked_p...

# %% [markdown]
# Let's get a feel for the available data, by grabbing the top 5 rows of `obs_sbn`:

# %%
pd.read_sql("SELECT * FROM obs_sbn LIMIT 5", con)
# Out:
#          id   trksub       trkid                      obsid  \
# 0  47633487  P10aawA  000001oj9Q  Kiv45q0000005jL701000007r
# 1  47633488  P10aawA  000001oj9Q  Kiv45q0000005jL701000007s
# 2  47633490  VE83847  000001pSO1  Kj9Bii0100005jrb0100004T2
# 3  47633491  VE83847  000001pSO1  Kj9Bii0100005jrb0100004T3
# 4  47633492  VE83847  000001pSO1  Kj9Bii0100005jrb0100004T4
#
#                       submission_id                  submission_block_id  \
# 0  2014-02-27T04:22:18.000_00005jL7  2014-02-27T04:22:18.000_00005jL7_01
# 1  2014-02-27T04:22:18.000_00005jL7  2014-02-27T04:22:18.000_00005jL7_01
# 2  2014-03-10T12:30:56.001_00005jrb  2014-03-10T12:30:56.001_00005jrb_01
# 3  2014-03-10T12:30:56.001_00005jrb  2014-03-10T12:30:56.001_00005jrb_01
# 4  2014-03-10T12:30:56.001_00005jrb  2014-03-10T12:30:56.001_00005jrb_01
#
#                                                obs80 status           ref  \
# 0  43996         C2014 02 26.42238 07 59 25.258+1...      P  MPS   502832
# 1  43996         C2014 02 26.43540 07 59 24.901+1...      P  MPS   502832
# 2  43996         C2014 03 10.14990 07 55 59.20 +1...      P  MPS   505761
# 3  43996         C2014 03 10.15633 07 55 59.15 +1...      P  MPS   505761
# 4  43996         C2014 03 10.16275 07 55 59.06 +1...      P  MPS   505761
#
#       healpix permid provid artsat mode  stn   trx   rcv   sys   ctr  pos1  \
# 0  1246427984  43996   None   None  CCD  F51  None  None  None  None  None
# 1  1246427986  43996   None   None  CCD  F51  None  None  None  None  None
# 2  1247970286  43996   None   None  CCD  G96  None  None  None  None  None
# 3  1247971652  43996   None   None  CCD  G96  None  None  None  None  None
# 4  1247971652  43996   None   None  CCD  G96  None  None  None  None  None
#
#    pos2  pos3 poscov11 poscov12 poscov13 poscov22 poscov23 poscov33  prog  \
# 0  None  None     None     None     None     None     None     None  None
# 1  None  None     None     None     None     None     None     None  None
# 2  None  None     None     None     None     None     None     None  None
# 3  None  None     None     None     None     None     None     None  None
# 4  None  None     None     None     None     None     None     None  None
#
#               obstime          ra        dec rastar decstar obscenter deltara  \
# 0 2014-02-26 10:08:14  119.855242  18.461572   None    None      None    None
# 1 2014-02-26 10:26:59  119.853754  18.461953   None    None      None    None
# 2 2014-03-10 03:35:51  118.996670  18.754030   None    None      None    None
# 3 2014-03-10 03:45:07  118.996460  18.754140   None    None      None    None
# 4 2014-03-10 03:54:22  118.996080  18.754280   None    None      None    None
#
#   deltadec  dist    pa rmsra rmsdec rmsdist rmspa rmscorr delay rmsdelay  \
# 0     None  None  None  None   None    None  None    None  None     None
# 1     None  None  None  None   None    None  None    None  None     None
# 2     None  None  None  None   None    None  None    None  None     None
# 3     None  None  None  None   None    None  None    None  None     None
# 4     None  None  None  None   None    None  None    None  None     None
#
#   doppler rmsdoppler astcat   mag rmsmag band photcat photap nucmag logsnr  \
# 0    None       None  2MASS  19.9   None    w    None   None   None   None
# 1    None       None  2MASS  19.8   None    w    None   None   None   None
# 2    None       None  UCAC4  19.8   None    V    None   None   None   None
# 3    None       None  UCAC4  19.7   None    V    None   None   None   None
# 4    None       None  UCAC4  19.8   None    V    None   None   None   None
#
#   seeing   exp rmsfit   com   frq  disc subfrm subfmt  prectime  precra  \
# 0   None  None   None  None  None  None   None    M92        10   0.001
# 1   None  None   None  None  None  None   None    M92        10   0.001
# 2   None  None   None  None  None  None   None    M92        10   0.010
# 3   None  None   None  None  None  None   None    M92        10   0.010
# 4   None  None   None  None  None  None   None    M92        10   0.010
#
#    precdec unctime notes remarks deprecated localuse nstars prev_desig  \
# 0     0.01    None  None    None       None     None   None       None
# 1     0.01    None  None    None       None     None   None       None
# 2     0.10    None  None    None       None     None   None       None
# 3     0.10    None  None    None       None     None   None       None
# 4     0.10    None  None    None       None     None   None       None
#
#   prev_ref rmstime                created_at                       updated_at  \
# 0     None    None 2017-07-10 00:00:00+00:00 2022-04-02 21:34:32.859424+00:00
# 1     None    None 2017-07-10 00:00:00+00:00 2022-04-02 21:34:32.860731+00:00
# 2     None    None 2017-07-10 00:00:00+00:00 2022-04-02 21:34:32.864786+00:00
# 3     None    None 2017-07-10 00:00:00+00:00 2022-04-02 21:34:32.866534+00:00
# 4     None    None 2017-07-10 00:00:00+00:00 2022-04-02 21:34:32.868178+00:00
#
#   trkmpc orbit_id designation_asterisk all_pub_ref shapeocc obssubid  \
# 0   None     None                 None        None     None     None
# 1   None     None                 None        None     None     None
# 2   None     None                 None        None     None     None
# 3   None     None                 None        None     None     None
# 4   None     None                 None        None     None     None
#
#   replacesobsid group_id
# 0          None     None
# 1          None     None
# 2          None     None
# 3          None     None
# 4          None     None

# %% [markdown]
# Let's give it something more to think about...:
